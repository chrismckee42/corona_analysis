# %%
## Covid Data Analysis

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\chris\Documents\Data_Projects\corona_analysis

# %%
os.chdir("../COVID-19/csse_covid_19_data/csse_covid_19_daily_reports_us")

# %%
print(os.getcwd())
# Out:
# C:\Users\chris\Documents\Data_Projects\COVID-19\csse_covid_19_data\csse_covid_19_daily_reports_us

# %%
file_list = os.listdir()
file_list.pop()
file_list
# Out:
# ['04-12-2020.csv',
#  '04-13-2020.csv',
#  '04-14-2020.csv',
#  '04-15-2020.csv',
#  '04-16-2020.csv',
#  '04-17-2020.csv',
#  '04-18-2020.csv',
#  '04-19-2020.csv',
#  '04-20-2020.csv',
#  '04-21-2020.csv',
#  '04-22-2020.csv',
#  '04-23-2020.csv',
#  '04-24-2020.csv',
#  '04-25-2020.csv',
#  '04-26-2020.csv',
#  '04-27-2020.csv',
#  '04-28-2020.csv',
#  '04-29-2020.csv',
#  '04-30-2020.csv',
#  '05-01-2020.csv',
#  '05-02-2020.csv',
#  '05-03-2020.csv',
#  '05-04-2020.csv',
#  '05-05-2020.csv',
#  '05-06-2020.csv',
#  '05-07-2020.csv',
#  '05-08-2020.csv',
#  '05-09-2020.csv',
#  '05-10-2020.csv']

# %%
import pandas as pd

# %%
stats = []

# %%
for i,item in enumerate(file_list):
    stats.append(pd.read_csv(item))

# %%
stats[2].head()
# Out:
#               Province_State Country_Region          Last_Update      Lat  \
# 0                    Alabama             US  2020-04-15 22:56:51  32.3182
# 1                     Alaska             US  2020-04-15 22:56:51  61.3707
# 2             American Samoa             US                  NaN -14.2710
# 3                    Arizona             US  2020-04-15 22:56:51  33.7298
# 4                   Arkansas             US  2020-04-15 22:56:51  34.9697
# 5                 California             US  2020-04-15 22:56:51  36.1162
# 6                   Colorado             US  2020-04-15 22:56:51  39.0598
# 7                Connecticut             US  2020-04-15 22:56:51  41.5978
# 8                   Delaware             US  2020-04-15 22:56:51  39.3185
# 9           Diamond Princess             US  2020-04-15 22:56:51      NaN
# 10      District of Columbia             US  2020-04-15 22:56:51  38.8974
# 11                   Florida             US  2020-04-15 22:56:51  27.7663
# ...

# %%
# Creates a list of states, cleans it up and converts it to a dictionary
states = stats[0].Province_State[0:55]
states = states.to_list()
states.remove("Guam")
states.remove("Diamond Princess")
states.remove("Grand Princess")
states.remove("Puerto Rico")
states_dict = dict(zip(states,[*range(0,51)]))
states_dict
# Out:
# {'Alabama': 0,
#  'Alaska': 1,
#  'Arizona': 2,
#  'Arkansas': 3,
#  'California': 4,
#  'Colorado': 5,
#  'Connecticut': 6,
#  'Delaware': 7,
#  'District of Columbia': 8,
#  'Florida': 9,
#  'Georgia': 10,
#  'Hawaii': 11,
#  'Idaho': 12,
#  'Illinois': 13,
#  'Indiana': 14,
#  'Iowa': 15,
#  'Kansas': 16,
#  'Kentucky': 17,
#  'Louisiana': 18,
#  'Maine': 19,
#  'Maryland': 20,
#  'Massachusetts': 21,
#  'Michigan': 22,
#  'Minnesota': 23,
#  'Mississippi': 24,
#  'Missouri': 25,
#  'Montana': 26,
#  'Nebraska': 27,
#  'Nevada': 28,
#  'New Hampshire': 29,
#  'New Jersey': 30,
#  'New Mexico': 31,
#  'New York': 32,
#  'North Carolina': 33,
#  'North Dakota': 34,
#  'Ohio': 35,
#  'Oklahoma': 36,
#  'Oregon': 37,
#  'Pennsylvania': 38,
#  'Rhode Island': 39,
#  'South Carolina': 40,
#  'South Dakota': 41,
#  'Tennessee': 42,
#  'Texas': 43,
#  'Utah': 44,
#  'Vermont': 45,
#  'Virginia': 46,
#  'Washington': 47,
#  'West Virginia': 48,
#  'Wisconsin': 49,
#  'Wyoming': 50}

# %%
import numpy as np

# %%
test2=np.array([[0]*3]*3)
test2[1][1] = 1
test2[0] = [2]*3
test2
# Out:
# array([[2, 2, 2],
#        [0, 1, 0],
#        [0, 0, 0]])

# %%
dir(test2)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_function__',
#  '__array_interface__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imatmul__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lshift__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
# ...

# %%
test = [0] * 51
for i in range(len(stats[0])):
    if stats[0].Province_State[i] in states_dict:
#         print(test[states_dict[stats[0].Province_State[i]]])
        test[states_dict[stats[0].Province_State[i]]] = stats[0].Confirmed[i]
test
# test = np.array([stats[0].Confirmed,stats[2].Confirmed])
# Out:
# [3563,
#  272,
#  3542,
#  1280,
#  22795,
#  7307,
#  12035,
#  1625,
#  1875,
#  19895,
#  12452,
#  499,
#  1407,
#  20852,
#  7928,
#  1587,
#  1344,
#  1963,
#  20595,
#  633,
#  8225,
#  25475,
#  24244,
#  1621,
#  2781,
#  4269,
#  387,
#  791,
#  2836,
#  929,
#  61850,
#  1245,
#  189033,
#  4570,
#  308,
#  6604,
#  1970,
#  1527,
#  22938,
#  2665,
#  3320,
#  730,
#  5508,
#  13677,
#  2303,
#  727,
#  5274,
#  10609,
#  593,
#  3341,
#  270]

# %%
dates = []
for file in file_list:
    dates.append(file[:-4])
dates
# Out:
# ['04-12-2020',
#  '04-13-2020',
#  '04-14-2020',
#  '04-15-2020',
#  '04-16-2020',
#  '04-17-2020',
#  '04-18-2020',
#  '04-19-2020',
#  '04-20-2020',
#  '04-21-2020',
#  '04-22-2020',
#  '04-23-2020',
#  '04-24-2020',
#  '04-25-2020',
#  '04-26-2020',
#  '04-27-2020',
#  '04-28-2020',
#  '04-29-2020',
#  '04-30-2020',
#  '05-01-2020',
#  '05-02-2020',
#  '05-03-2020',
#  '05-04-2020',
#  '05-05-2020',
#  '05-06-2020',
#  '05-07-2020',
#  '05-08-2020',
#  '05-09-2020',
#  '05-10-2020']

# %%
confirmed = np.array([[0]*3]*51)
np.array([stats[0].Confirmed[0:58]])
for i,x in enumerate(stats):
    if i!= 0:
        confirmed = np.append(confirmed,[x.Confirmed[0:58]],axis=0)
confirmed
# Out:
# array([[ 3563,   272,  3542, ...,     0,    11,     0],
#        [ 3734,   277,     0, ...,   611,  3428,   275],
#        [ 3953,   285,     0, ...,   640,  3555,   282],
#        ...,
#        [ 9385,   377,     0, ...,  1323,  9590,   644],
#        [ 9668,   378,     0, ...,  1323,  9939,   653],
#        [ 9889,   379,     0, ...,  1360, 10219,   662]], dtype=int64)

# %%
print(len(confirmed),len(stats))
# Out:
# 29 29

# %%
transpose(test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-2f64772062b2> in <module>
# ----> 1 transpose(test)
#
# NameError: name 'transpose' is not defined

# %%
test.transpose()
# Out:
# array([[  3563,   3953],
#        [   272,    285],
#        [  3542,      0],
#        [  1280,   3809],
#        [ 22795,   1498],
#        [  7307,  25356],
#        [ 12035,   7950],
#        [  1625,  13989],
#        [    49,   1926],
#        [  1875,     49],
#        [ 19895,   2058],
#        [ 12452,  21628],
#        [   103,  14578],
#        [   133,    103],
#        [   499,    133],
#        [  1407,    511],
#        [ 20852,   1464],
#        [  7928,  23248],
#        [  1587,   8527],
#        [  1344,   1899],
#        [  1963,   1441],
#        [ 20595,   2048],
#        [   633,  21518],
#        [  8225,    735],
#        [ 25475,   9472],
#        [ 24244,  28164],
#        [  1621,  27001],
#        [  2781,   1695],
#        [  4269,   3087],
#        [   387,   4746],
#        [   791,    399],
#        [  2836,    897],
#        [   929,   3134],
#        [ 61850,    922],
#        [  1245,  68824],
#        [189033,   1345],
#        [  4570, 203020],
# ...
